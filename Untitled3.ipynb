# %% [markdown]
# <a href="https://colab.research.google.com/github/manishkrb194-commits/advace-python-mysql-task-2-/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
string = 'hello 12 hi 89.howdy 34'
pattern =r'\d+'
result = re.findall(pattern,string)
print(result)
# Out:
# ['12', '89', '34']

# %%
#largest number
numbers = [10, 25, 5, 40, 15]
largest = max(numbers)
print("Largest element:", largest)
# Out:
# Largest element: 40

# %%
# number is odd and even
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Enter a number: 34
# Even number

# %%
# reverse string
text = "hello"
reverse = ""

for char in text:
    reverse = char + reverse

print("Reversed string:", reverse)

# %%
# count the vowel
text = input("Enter a string: ")
count = 0

for char in text:
    if char.upper() in "aeiouAEIO":
        count += 1

print("Number of vowels:", count)
# Out:
# Enter a string: manish
# Number of vowels: 2

# %%
#sum of two number
num1 = int(input("enter the number"))
num2 = int(input("enter the number"))
sum = num1 + num2
print("sum of two number",sum)
# Out:
# enter the number2
# enter the number4
# sum of two number 6

# %%
# string is palindrome or not
sentence = input("enter the string")


if sentence == sentence[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# enter the stringnaman
# Palindrome

# %%
# find fibonacci  series
n = int(input("Enter number of terms: "))

a, b = 0, 1

for i in range(n):
    print(a,end = "      ")
    a,b =b,b+a
# Out:
# Enter number of terms: 5
# 0      1      1      2      3
